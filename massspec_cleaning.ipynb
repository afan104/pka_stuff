# %%
# %reset
import pandas as pd
import os
import string
import re
import numpy as np

# %%
f = "./ms_data/" + "".join(os.listdir("./ms_data"))

data = pd.read_excel(f, sheet_name = 0, usecols="B,F,H:X") # names =
# Out:
#        Gene                                            mod_seq  \
# 0      YRO2                                    SSDSDSS[Ph]IKEK
# 1     DAL80  VLSDSLKLPSPT[Ph]LSAAAGVDDC[Cm]DGEDHPTC[Cm]QNC[...
# 2      LEE1  RNS[Ph]QSANEM[Ox]LASQIQDFQNIPR-and-RNSQS[Ph]AN...
# 3      YB8A                            HQNTYSPEDS[Ph]VEFDRFDDK
# 4      PUT4  HSAGVVTC[Cm]ADDVSGDGSGGDTKKEEDVVQVTES[Ph]PSSGS...
# ...     ...                                                ...
# 7802   HOSC                                NFHAEVS[Ph]TPQVLSAK
# 7803   MPP6    EFT[Ph]GSQDDGEDEYDLDK-and-EFTGS[Ph]QDDGEDEYDLDK
# 7804  PAR32  SHQSLHAT[Ph]T[Ph]S[Ph]SPNNNAPIVVGR-and-S[Ph]HQ...
# 7805   OSH2                        ES[Ph]LENDKEQESDTTASTLGQIAK
# 7806   PIK1                                      S[Ph]FDDTIELK
#
#                                                phos_pos       WT_SD_1  \
# 0                                                   302  2.000000e+03
# ...
